# %%
import numpy as np
import pandas as pd

df1 = pd.read_csv("book1-100k.csv")
for i in range(1, 10):
    file_name = f"book{i*100}k-{(i+1)*100}k.csv"
    df = pd.read_csv(file_name)
    globals()[f"df{i+1}"] = df
df10.head()
# Out:
#        Id                                               Name          Authors  \
# 0  900000                                Cabinet 03: Weather  Jeffrey Kastner
# 1  900001  Workouts in a Binder for Swimmers, Triathletes...      Nick Hansen
# 2  900002                         Las 120 jornadas de Sodoma  Marquis de Sade
# 3  900004  The Traveler: An American Odyssey in the Himal...      Eric Hansen
# 4  900006                                     Vertical Smile   Richard Condon
#
#          ISBN  Rating  PublishYear  PublishMonth  PublishDay  \
# 0  1932698019    4.00         2004             2           1
# 1  1931382743    4.48         2005            18          11
# 2  8472233847    3.12         1992             1           3
# 3  0871563509    4.18         1995             6           6
# 4  0297994026    3.74         1972            20           4
#
#                          Publisher RatingDist5 RatingDist4 RatingDist3  \
# ...

# %%
for i in range(1, 11):
    df_name = f"df{i}"
    print(f"Bảng dữ liệu {i} có {len(globals()[df_name].columns)} cột.")
# Out:
# Bảng dữ liệu 1 có 18 cột.
# Bảng dữ liệu 2 có 18 cột.
# Bảng dữ liệu 3 có 18 cột.
# Bảng dữ liệu 4 có 18 cột.
# Bảng dữ liệu 5 có 18 cột.
# Bảng dữ liệu 6 có 18 cột.
# Bảng dữ liệu 7 có 19 cột.
# Bảng dữ liệu 8 có 20 cột.
# Bảng dữ liệu 9 có 20 cột.
# Bảng dữ liệu 10 có 20 cột.

# %%
df_list = [v for v in globals().values() if isinstance(v, pd.DataFrame)]
all_columns = set().union(*[df.columns for df in df_list])
for df_name, df in df_list:
    missing_columns = all_columns - set(df.columns)
    if missing_columns:
        print(f"\nDataframe {df_name} thiếu các cột: {missing_columns}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 3
#       1 df_list = [v for v in globals().values() if isinstance(v, pd.DataFrame)]
#       2 all_columns = set().union(*[df.columns for df in df_list])
# ----> 3 for df_name,df in df_list:
#       4     missing_columns = all_columns - set(df.columns)
#       5     if missing_columns:
#
# ValueError: too many values to unpack (expected 2)

# %%
# Out:
# 109
